# %% [markdown]
# # Background Subtraction Method
#
# This notebook is used to determine the most appropriate background subtraction method to use from the range of options available for the [Background2D](http://photutils.readthedocs.io/en/stable/photutils/background.html) function.

# %%
# %load_ext autotime

from astropy.io import fits
import photutils
from photutils import Background2D, SigmaClip, MeanBackground, MMMBackground, \
    MedianBackground, SExtractorBackground, BkgIDWInterpolator, BkgZoomInterpolator

import numpy as np

from piaa import observation
from pocs.utils import current_time

# Load the RGB mask arrays and the camera bias
rgb_masks = np.load('/var/panoptes/rgb_masks.numpy')
camera_bias = 2048

# %% [markdown]
# ### Fields to test
#
# We test two separate fields, one on a new moon and relatively sparse in terms of stellar density, the other near the galactic equator and crowded

# %%
# Test a few different fields that have different conditions
image_dirs = {
    'crowded_field': '/var/panoptes/images/fields/Kic8462852/14d3bd/20170416T124816/',
    'new_moon': '/var/panoptes/images/fields/HatP20/14d3bd/20170128T053449/',
}
# Out:
# time: 1.45 ms

# %% [markdown]
# ### Box and grid size
#
# We test two different box sizes that are both integer multiples of the full image dimensions. The two sizes are complementary, so for the large box size of $316 \times 434$ a grid of $11 \times 12$ boxes are created. For the smaller box size the opposite is true.

# %%
# Image size: 3476 x 5208
box_size = [
    (316, 434),
    (11, 12)
]
# Out:
# time: 1.83 ms

# %% [markdown]
# ### Options to test

# %%
estimators = [SExtractorBackground(), MedianBackground(), MeanBackground(), MMMBackground()]
interpolators = [BkgZoomInterpolator()]
sigmas = [3, 4, 5]
iters = [5, 7, 10]
# Out:
# time: 2.4 ms

# %% [markdown]
# ### Perform test
#
# Run through the various options and output the total time spent with each option

# %%
for name, image_dir in image_dirs.items():
    obs = observation.Observation(image_dir, verbose=True)

    data = fits.getdata(obs.files[1]) - camera_bias
    
    print("{}".format(name))
    for h, w in box_size:
        print("\tBox: {} {}".format(h, w))
        for estimator in estimators:
            print("\t{}".format(estimator))
            for interpolator in interpolators:
                print("\t{}".format(interpolator))
                for sigma in sigmas:
                    for iterations in iters:
                        print("\tSigma: {} Iters: {}".format(sigma, iterations))
                        start_time = current_time()
                        for color, mask in zip(['R', 'G', 'B'], rgb_masks):
                            sigma_clip = SigmaClip(sigma=sigma, iters=iterations)
                            bkg = Background2D(data, (h, w), filter_size=(3, 3),
                                           sigma_clip=sigma_clip, bkg_estimator=estimator, mask=~mask,
                                           interpolator=interpolator)
                            end_time = current_time()

                            print("\t{} Background\t Value: {:.02f}\t RMS: {:.02f}".format(
                                color, bkg.background_median, bkg.background_rms_median))

                        print("\tTotal time: {:0.2f} seconds\n".format((end_time - start_time).sec))
# Out:
# ********************************************************************************
# Setting up Observation for analysis
# crowded_field
# 	Box: 316 434
# 	<photutils.background.core.SExtractorBackground object at 0x7fd6b02aa080>
# 	<photutils.background.background_2d.BkgZoomInterpolator object at 0x7fd6b02aa550>
# 	Sigma: 3 Iters: 5
# 	R Background	 Value: 166.14	 RMS: 16.26
# 	G Background	 Value: 382.54	 RMS: 23.56
# 	B Background	 Value: 327.96	 RMS: 20.25
# 	Total time: 73.29 seconds
#
# 	Sigma: 3 Iters: 7
# 	R Background	 Value: 166.21	 RMS: 16.13
# 	G Background	 Value: 382.90	 RMS: 23.22
# 	B Background	 Value: 327.29	 RMS: 20.15
# 	Total time: 78.63 seconds
#
# 	Sigma: 3 Iters: 10
# 	R Background	 Value: 166.21	 RMS: 16.13
# 	G Background	 Value: 382.90	 RMS: 23.20
# 	B Background	 Value: 327.32	 RMS: 20.15
# 	Total time: 96.21 seconds
#
# 	Sigma: 4 Iters: 5
# 	R Background	 Value: 164.86	 RMS: 18.63
# 	G Background	 Value: 380.38	 RMS: 27.73
# 	B Background	 Value: 327.04	 RMS: 22.73
# 	Total time: 66.92 seconds
#
# 	Sigma: 4 Iters: 7
# 	R Background	 Value: 164.96	 RMS: 18.42
# 	G Background	 Value: 380.93	 RMS: 27.17
# 	B Background	 Value: 327.20	 RMS: 22.55
# 	Total time: 83.66 seconds
#
# 	Sigma: 4 Iters: 10
# 	R Background	 Value: 164.96	 RMS: 18.42
# 	G Background	 Value: 381.02	 RMS: 27.09
# 	B Background	 Value: 327.20	 RMS: 22.55
# 	Total time: 101.45 seconds
#
# 	Sigma: 5 Iters: 5
# 	R Background	 Value: 163.11	 RMS: 21.03
# 	G Background	 Value: 379.11	 RMS: 31.83
# 	B Background	 Value: 324.90	 RMS: 25.31
# 	Total time: 66.98 seconds
#
# 	Sigma: 5 Iters: 7
# 	R Background	 Value: 163.31	 RMS: 20.65
# 	G Background	 Value: 378.54	 RMS: 31.11
# 	B Background	 Value: 325.22	 RMS: 24.91
# 	Total time: 78.28 seconds
#
# 	Sigma: 5 Iters: 10
# 	R Background	 Value: 163.36	 RMS: 20.65
# 	G Background	 Value: 378.58	 RMS: 31.04
# 	B Background	 Value: 325.22	 RMS: 24.90
# 	Total time: 95.47 seconds
#
# 	<photutils.background.core.MedianBackground object at 0x7fd6b02aa198>
# 	<photutils.background.background_2d.BkgZoomInterpolator object at 0x7fd6b02aa550>
# 	Sigma: 3 Iters: 5
# 	R Background	 Value: 167.50	 RMS: 16.26
# 	G Background	 Value: 385.50	 RMS: 23.56
# 	B Background	 Value: 330.00	 RMS: 20.25
# 	Total time: 69.91 seconds
#
# 	Sigma: 3 Iters: 7
# 	R Background	 Value: 167.00	 RMS: 16.13
# 	G Background	 Value: 385.50	 RMS: 23.22
# 	B Background	 Value: 329.50	 RMS: 20.15
# 	Total time: 79.78 seconds
#
# 	Sigma: 3 Iters: 10
# 	R Background	 Value: 167.00	 RMS: 16.13
# 	G Background	 Value: 385.50	 RMS: 23.20
# 	B Background	 Value: 329.50	 RMS: 20.15
# 	Total time: 98.82 seconds
#
# 	Sigma: 4 Iters: 5
# 	R Background	 Value: 168.00	 RMS: 18.63
# 	G Background	 Value: 386.50	 RMS: 27.73
# 	B Background	 Value: 330.50	 RMS: 22.73
# 	Total time: 71.61 seconds
#
# 	Sigma: 4 Iters: 7
# 	R Background	 Value: 168.00	 RMS: 18.42
# 	G Background	 Value: 386.50	 RMS: 27.17
# 	B Background	 Value: 330.50	 RMS: 22.55
# 	Total time: 79.58 seconds
#
# 	Sigma: 4 Iters: 10
# 	R Background	 Value: 168.00	 RMS: 18.42
# 	G Background	 Value: 386.50	 RMS: 27.09
# 	B Background	 Value: 330.50	 RMS: 22.55
# 	Total time: 92.82 seconds
#
# 	Sigma: 5 Iters: 5
# 	R Background	 Value: 168.00	 RMS: 21.03
# 	G Background	 Value: 387.00	 RMS: 31.83
# 	B Background	 Value: 330.50	 RMS: 25.31
# 	Total time: 63.08 seconds
#
# 	Sigma: 5 Iters: 7
# 	R Background	 Value: 168.00	 RMS: 20.65
# 	G Background	 Value: 386.50	 RMS: 31.11
# 	B Background	 Value: 330.50	 RMS: 24.91
# 	Total time: 75.23 seconds
#
# 	Sigma: 5 Iters: 10
# 	R Background	 Value: 168.00	 RMS: 20.65
# 	G Background	 Value: 386.50	 RMS: 31.04
# 	B Background	 Value: 330.50	 RMS: 24.90
# 	Total time: 92.94 seconds
#
# 	<photutils.background.core.MeanBackground object at 0x7fd6b02aa208>
# 	<photutils.background.background_2d.BkgZoomInterpolator object at 0x7fd6b02aa550>
# 	Sigma: 3 Iters: 5
# 	R Background	 Value: 169.05	 RMS: 16.26
# 	G Background	 Value: 387.74	 RMS: 23.56
# 	B Background	 Value: 330.81	 RMS: 20.25
# 	Total time: 62.31 seconds
#
# 	Sigma: 3 Iters: 7
# 	R Background	 Value: 168.76	 RMS: 16.13
# 	G Background	 Value: 387.41	 RMS: 23.22
# 	B Background	 Value: 330.68	 RMS: 20.15
# 	Total time: 73.63 seconds
#
# 	Sigma: 3 Iters: 10
# 	R Background	 Value: 168.76	 RMS: 16.13
# 	G Background	 Value: 387.41	 RMS: 23.20
# 	B Background	 Value: 330.68	 RMS: 20.15
# 	Total time: 92.16 seconds
#
# 	Sigma: 4 Iters: 5
# 	R Background	 Value: 170.52	 RMS: 18.63
# 	G Background	 Value: 390.74	 RMS: 27.73
# 	B Background	 Value: 332.36	 RMS: 22.73
# 	Total time: 67.53 seconds
#
# 	Sigma: 4 Iters: 7
# 	R Background	 Value: 170.44	 RMS: 18.42
# 	G Background	 Value: 390.31	 RMS: 27.17
# 	B Background	 Value: 332.23	 RMS: 22.55
# 	Total time: 81.84 seconds
#
# 	Sigma: 4 Iters: 10
# 	R Background	 Value: 170.44	 RMS: 18.42
# 	G Background	 Value: 390.28	 RMS: 27.09
# 	B Background	 Value: 332.23	 RMS: 22.55
# 	Total time: 102.21 seconds
#
# 	Sigma: 5 Iters: 5
# 	R Background	 Value: 171.73	 RMS: 21.03
# 	G Background	 Value: 393.21	 RMS: 31.83
# 	B Background	 Value: 333.70	 RMS: 25.31
# 	Total time: 70.08 seconds
#
# 	Sigma: 5 Iters: 7
# 	R Background	 Value: 171.60	 RMS: 20.65
# 	G Background	 Value: 392.71	 RMS: 31.11
# 	B Background	 Value: 333.46	 RMS: 24.91
# 	Total time: 84.36 seconds
#
# 	Sigma: 5 Iters: 10
# 	R Background	 Value: 171.57	 RMS: 20.65
# 	G Background	 Value: 392.61	 RMS: 31.04
# 	B Background	 Value: 333.44	 RMS: 24.90
# 	Total time: 102.19 seconds
#
# 	<photutils.background.core.MMMBackground object at 0x7fd6b02aa4e0>
# 	<photutils.background.background_2d.BkgZoomInterpolator object at 0x7fd6b02aa550>
# 	Sigma: 3 Iters: 5
# 	R Background	 Value: 165.44	 RMS: 16.26
# 	G Background	 Value: 381.78	 RMS: 23.56
# 	B Background	 Value: 327.28	 RMS: 20.25
# 	Total time: 71.33 seconds
#
# 	Sigma: 3 Iters: 7
# 	R Background	 Value: 165.80	 RMS: 16.13
# 	G Background	 Value: 382.15	 RMS: 23.22
# 	B Background	 Value: 326.56	 RMS: 20.15
# 	Total time: 85.00 seconds
#
# 	Sigma: 3 Iters: 10
# 	R Background	 Value: 165.80	 RMS: 16.13
# 	G Background	 Value: 382.15	 RMS: 23.20
# 	B Background	 Value: 326.60	 RMS: 20.15
# 	Total time: 97.32 seconds
#
# 	Sigma: 4 Iters: 5
# 	R Background	 Value: 163.73	 RMS: 18.63
# 	G Background	 Value: 378.72	 RMS: 27.73
# 	B Background	 Value: 325.81	 RMS: 22.73
# 	Total time: 64.69 seconds
#
# 	Sigma: 4 Iters: 7
# 	R Background	 Value: 164.06	 RMS: 18.42
# 	G Background	 Value: 379.34	 RMS: 27.17
# 	B Background	 Value: 326.02	 RMS: 22.55
# 	Total time: 76.67 seconds
#
# 	Sigma: 4 Iters: 10
# 	R Background	 Value: 164.06	 RMS: 18.42
# 	G Background	 Value: 379.41	 RMS: 27.09
# 	B Background	 Value: 326.02	 RMS: 22.55
# 	Total time: 94.79 seconds
#
# 	Sigma: 5 Iters: 5
# 	R Background	 Value: 161.41	 RMS: 21.03
# 	G Background	 Value: 377.05	 RMS: 31.83
# 	B Background	 Value: 322.87	 RMS: 25.31
# 	Total time: 64.54 seconds
#
# 	Sigma: 5 Iters: 7
# 	R Background	 Value: 161.61	 RMS: 20.65
# 	G Background	 Value: 375.86	 RMS: 31.11
# 	B Background	 Value: 323.39	 RMS: 24.91
# 	Total time: 78.06 seconds
#
# 	Sigma: 5 Iters: 10
# 	R Background	 Value: 161.65	 RMS: 20.65
# 	G Background	 Value: 375.97	 RMS: 31.04
# 	B Background	 Value: 323.39	 RMS: 24.90
# 	Total time: 94.29 seconds
#
# 	Box: 11 12
# 	<photutils.background.core.SExtractorBackground object at 0x7fd6b02aa080>
# 	<photutils.background.background_2d.BkgZoomInterpolator object at 0x7fd6b02aa550>
# 	Sigma: 3 Iters: 5
# 	R Background	 Value: 165.85	 RMS: 14.64
# 	G Background	 Value: 383.36	 RMS: 20.50
# 	B Background	 Value: 328.65	 RMS: 17.77
# 	Total time: 101.58 seconds
#
# 	Sigma: 3 Iters: 7
# 	R Background	 Value: 165.85	 RMS: 14.62
# 	G Background	 Value: 383.41	 RMS: 20.43
# 	B Background	 Value: 328.65	 RMS: 17.76
# 	Total time: 113.34 seconds
#
# 	Sigma: 3 Iters: 10
# 	R Background	 Value: 165.85	 RMS: 14.62
# 	G Background	 Value: 383.40	 RMS: 20.41
# 	B Background	 Value: 328.64	 RMS: 17.75
# 	Total time: 131.81 seconds
#
# 	Sigma: 4 Iters: 5
# 	R Background	 Value: 165.35	 RMS: 15.99
# 	G Background	 Value: 382.52	 RMS: 23.16
# 	B Background	 Value: 327.90	 RMS: 19.05
# 	Total time: 101.23 seconds
#
# 	Sigma: 4 Iters: 7
# 	R Background	 Value: 165.35	 RMS: 15.99
# 	G Background	 Value: 382.55	 RMS: 23.11
# 	B Background	 Value: 327.90	 RMS: 19.05
# 	Total time: 113.11 seconds
#
# 	Sigma: 4 Iters: 10
# 	R Background	 Value: 165.35	 RMS: 15.99
# 	G Background	 Value: 382.55	 RMS: 23.10
# 	B Background	 Value: 327.90	 RMS: 19.05
# 	Total time: 130.08 seconds
#
# 	Sigma: 5 Iters: 5
# 	R Background	 Value: 165.00	 RMS: 16.59
# 	G Background	 Value: 381.98	 RMS: 25.40
# 	B Background	 Value: 327.29	 RMS: 19.66
# 	Total time: 101.08 seconds
#
# 	Sigma: 5 Iters: 7
# 	R Background	 Value: 165.00	 RMS: 16.59
# 	G Background	 Value: 381.99	 RMS: 25.39
# 	B Background	 Value: 327.29	 RMS: 19.66
# 	Total time: 112.50 seconds
#
# 	Sigma: 5 Iters: 10
# 	R Background	 Value: 165.00	 RMS: 16.59
# 	G Background	 Value: 382.00	 RMS: 25.39
# 	B Background	 Value: 327.29	 RMS: 19.66
# 	Total time: 128.72 seconds
#
# 	<photutils.background.core.MedianBackground object at 0x7fd6b02aa198>
# 	<photutils.background.background_2d.BkgZoomInterpolator object at 0x7fd6b02aa550>
# 	Sigma: 3 Iters: 5
# 	R Background	 Value: 167.00	 RMS: 14.64
# 	G Background	 Value: 386.00	 RMS: 20.50
# 	B Background	 Value: 330.00	 RMS: 17.77
# 	Total time: 98.15 seconds
#
# 	Sigma: 3 Iters: 7
# 	R Background	 Value: 167.00	 RMS: 14.62
# 	G Background	 Value: 386.00	 RMS: 20.43
# 	B Background	 Value: 330.00	 RMS: 17.76
# 	Total time: 110.28 seconds
#
# 	Sigma: 3 Iters: 10
# 	R Background	 Value: 167.00	 RMS: 14.62
# 	G Background	 Value: 386.00	 RMS: 20.41
# 	B Background	 Value: 330.00	 RMS: 17.75
# 	Total time: 126.13 seconds
#
# 	Sigma: 4 Iters: 5
# 	R Background	 Value: 167.50	 RMS: 15.99
# 	G Background	 Value: 386.50	 RMS: 23.16
# 	B Background	 Value: 330.50	 RMS: 19.05
# 	Total time: 97.74 seconds
#
# 	Sigma: 4 Iters: 7
# 	R Background	 Value: 167.50	 RMS: 15.99
# 	G Background	 Value: 386.50	 RMS: 23.11
# 	B Background	 Value: 330.50	 RMS: 19.05
# 	Total time: 109.70 seconds
#
# 	Sigma: 4 Iters: 10
# 	R Background	 Value: 167.50	 RMS: 15.99
# 	G Background	 Value: 386.50	 RMS: 23.10
# 	B Background	 Value: 330.50	 RMS: 19.05
# 	Total time: 125.87 seconds
#
# 	Sigma: 5 Iters: 5
# 	R Background	 Value: 168.00	 RMS: 16.59
# 	G Background	 Value: 387.00	 RMS: 25.40
# 	B Background	 Value: 330.50	 RMS: 19.66
# 	Total time: 98.32 seconds
#
# 	Sigma: 5 Iters: 7
# 	R Background	 Value: 168.00	 RMS: 16.59
# 	G Background	 Value: 387.00	 RMS: 25.39
# 	B Background	 Value: 330.50	 RMS: 19.66
# 	Total time: 109.46 seconds
#
# 	Sigma: 5 Iters: 10
# 	R Background	 Value: 168.00	 RMS: 16.59
# 	G Background	 Value: 391.68	 RMS: 25.39
# 	B Background	 Value: 332.78	 RMS: 19.66
# 	Total time: 108.71 seconds
#
# 	Sigma: 5 Iters: 10
# 	R Background	 Value: 170.39	 RMS: 16.59
# 	G Background	 Value: 391.68	 RMS: 25.39
# 	B Background	 Value: 332.78	 RMS: 19.66
# 	Total time: 124.33 seconds
#
# 	<photutils.background.core.MMMBackground object at 0x7fd6b02aa4e0>
# 	<photutils.background.background_2d.BkgZoomInterpolator object at 0x7fd6b02aa550>
# 	Sigma: 3 Iters: 5
# 	R Background	 Value: 164.33	 RMS: 14.64
# 	G Background	 Value: 381.83	 RMS: 20.50
# 	B Background	 Value: 327.34	 RMS: 17.77
# 	Total time: 99.57 seconds
#
# 	Sigma: 3 Iters: 7
# 	R Background	 Value: 164.40	 RMS: 14.62
# 	G Background	 Value: 382.05	 RMS: 20.43
# 	B Background	 Value: 327.43	 RMS: 17.76
# 	Total time: 112.37 seconds
#
# 	Sigma: 3 Iters: 10
# 	R Background	 Value: 164.43	 RMS: 14.62
# 	G Background	 Value: 382.12	 RMS: 20.41
# 	B Background	 Value: 327.43	 RMS: 17.75
# 	Total time: 129.86 seconds
#
# 	Sigma: 4 Iters: 5
# 	R Background	 Value: 162.14	 RMS: 15.99
# 	G Background	 Value: 378.87	 RMS: 23.16
# 	B Background	 Value: 324.78	 RMS: 19.05
# 	Total time: 102.16 seconds
#
# 	Sigma: 4 Iters: 7
# 	R Background	 Value: 162.15	 RMS: 15.99
# 	G Background	 Value: 379.00	 RMS: 23.11
# 	B Background	 Value: 324.78	 RMS: 19.05
# 	Total time: 111.81 seconds
#
# 	Sigma: 4 Iters: 10
# 	R Background	 Value: 162.15	 RMS: 15.99
# 	G Background	 Value: 379.03	 RMS: 23.10
# 	B Background	 Value: 324.78	 RMS: 19.05
# 	Total time: 131.07 seconds
#
# 	Sigma: 5 Iters: 5
# 	R Background	 Value: 160.89	 RMS: 16.59
# 	G Background	 Value: 375.86	 RMS: 25.40
# 	B Background	 Value: 323.20	 RMS: 19.66
# 	Total time: 102.33 seconds
#
# 	Sigma: 5 Iters: 7
# 	R Background	 Value: 160.89	 RMS: 16.59
# 	G Background	 Value: 375.89	 RMS: 25.39
# 	B Background	 Value: 323.20	 RMS: 19.66
# 	Total time: 112.63 seconds
#
# 	Sigma: 5 Iters: 10
# 	R Background	 Value: 160.89	 RMS: 16.59
# 	G Background	 Value: 375.89	 RMS: 25.39
# 	B Background	 Value: 323.20	 RMS: 19.66
# 	Total time: 129.14 seconds
#
# ********************************************************************************
# Setting up Observation for analysis
# new_moon
# 	Box: 316 434
# 	<photutils.background.core.SExtractorBackground object at 0x7fd6b02aa080>
# 	<photutils.background.background_2d.BkgZoomInterpolator object at 0x7fd6b02aa550>
# 	Sigma: 3 Iters: 5
# 	R Background	 Value: 45.46	 RMS: 10.77
# 	G Background	 Value: 69.82	 RMS: 12.10
# 	B Background	 Value: 43.61	 RMS: 11.02
# 	Total time: 65.74 seconds
#
# 	Sigma: 3 Iters: 7
# 	R Background	 Value: 45.46	 RMS: 10.73
# 	G Background	 Value: 69.82	 RMS: 11.91
# 	B Background	 Value: 43.59	 RMS: 10.89
# 	Total time: 81.26 seconds
#
# 	Sigma: 3 Iters: 10
# 	R Background	 Value: 45.46	 RMS: 10.73
# 	G Background	 Value: 69.82	 RMS: 11.91
# 	B Background	 Value: 43.59	 RMS: 10.87
# 	Total time: 96.00 seconds
#
# 	Sigma: 4 Iters: 5
# 	R Background	 Value: 44.94	 RMS: 11.91
# 	G Background	 Value: 69.10	 RMS: 13.89
# 	B Background	 Value: 43.11	 RMS: 12.42
# 	Total time: 65.80 seconds
#
# 	Sigma: 4 Iters: 7
# 	R Background	 Value: 45.04	 RMS: 11.82
# 	G Background	 Value: 69.31	 RMS: 13.62
# 	B Background	 Value: 43.30	 RMS: 12.23
# 	Total time: 77.29 seconds
#
# 	Sigma: 4 Iters: 10
# 	R Background	 Value: 45.04	 RMS: 11.82
# 	G Background	 Value: 69.31	 RMS: 13.61
# 	B Background	 Value: 43.30	 RMS: 12.23
# 	Total time: 95.18 seconds
#
# 	Sigma: 5 Iters: 5
# 	R Background	 Value: 44.75	 RMS: 13.03
# 	G Background	 Value: 67.82	 RMS: 15.92
# 	B Background	 Value: 42.19	 RMS: 13.83
# 	Total time: 65.43 seconds
#
# 	Sigma: 5 Iters: 7
# 	R Background	 Value: 44.80	 RMS: 12.87
# 	G Background	 Value: 68.40	 RMS: 15.42
# 	B Background	 Value: 42.59	 RMS: 13.49
# 	Total time: 77.50 seconds
#
# 	Sigma: 5 Iters: 10
# 	R Background	 Value: 44.81	 RMS: 12.87
# 	G Background	 Value: 68.53	 RMS: 15.33
# 	B Background	 Value: 42.63	 RMS: 13.48
# 	Total time: 95.54 seconds
#
# 	<photutils.background.core.MedianBackground object at 0x7fd6b02aa198>
# 	<photutils.background.background_2d.BkgZoomInterpolator object at 0x7fd6b02aa550>
# 	Sigma: 3 Iters: 5
# 	R Background	 Value: 46.50	 RMS: 10.77
# 	G Background	 Value: 71.00	 RMS: 12.10
# 	B Background	 Value: 44.75	 RMS: 11.02
# 	Total time: 62.80 seconds
#
# 	Sigma: 3 Iters: 7
# 	R Background	 Value: 46.50	 RMS: 10.73
# 	G Background	 Value: 71.00	 RMS: 11.91
# 	B Background	 Value: 44.50	 RMS: 10.89
# 	Total time: 74.23 seconds
#
# 	Sigma: 3 Iters: 10
# 	R Background	 Value: 46.50	 RMS: 10.73
# 	G Background	 Value: 71.00	 RMS: 11.91
# 	B Background	 Value: 44.50	 RMS: 10.87
# 	Total time: 92.93 seconds
#
# 	Sigma: 4 Iters: 5
# 	R Background	 Value: 47.00	 RMS: 11.91
# 	G Background	 Value: 71.75	 RMS: 13.89
# 	B Background	 Value: 45.00	 RMS: 12.42
# 	Total time: 64.15 seconds
#
# 	Sigma: 4 Iters: 7
# 	R Background	 Value: 47.00	 RMS: 11.82
# 	G Background	 Value: 71.00	 RMS: 13.62
# 	B Background	 Value: 45.00	 RMS: 12.23
# 	Total time: 74.89 seconds
#
# 	Sigma: 4 Iters: 10
# 	R Background	 Value: 47.00	 RMS: 11.82
# 	G Background	 Value: 71.00	 RMS: 13.61
# 	B Background	 Value: 45.00	 RMS: 12.23
# 	Total time: 92.55 seconds
#
# 	Sigma: 5 Iters: 5
# 	R Background	 Value: 47.00	 RMS: 13.03
# 	G Background	 Value: 72.00	 RMS: 15.92
# 	B Background	 Value: 45.00	 RMS: 13.83
# 	Total time: 62.95 seconds
#
# 	Sigma: 5 Iters: 7
# 	R Background	 Value: 47.00	 RMS: 12.87
# 	G Background	 Value: 72.00	 RMS: 15.42
# 	B Background	 Value: 45.00	 RMS: 13.49
# 	Total time: 73.94 seconds
#
# 	Sigma: 5 Iters: 10
# 	R Background	 Value: 47.00	 RMS: 12.87
# 	G Background	 Value: 72.00	 RMS: 15.33
# 	B Background	 Value: 45.00	 RMS: 13.48
# 	Total time: 91.43 seconds
#
# 	<photutils.background.core.MeanBackground object at 0x7fd6b02aa208>
# 	<photutils.background.background_2d.BkgZoomInterpolator object at 0x7fd6b02aa550>
# 	Sigma: 3 Iters: 5
# 	R Background	 Value: 47.30	 RMS: 10.77
# 	G Background	 Value: 72.05	 RMS: 12.10
# 	B Background	 Value: 45.10	 RMS: 11.02
# 	Total time: 60.54 seconds
#
# 	Sigma: 3 Iters: 7
# 	R Background	 Value: 47.27	 RMS: 10.73
# 	G Background	 Value: 71.81	 RMS: 11.91
# 	B Background	 Value: 45.05	 RMS: 10.89
# 	Total time: 74.31 seconds
#
# 	Sigma: 3 Iters: 10
# 	R Background	 Value: 47.27	 RMS: 10.73
# 	G Background	 Value: 71.76	 RMS: 11.91
# 	B Background	 Value: 45.05	 RMS: 10.87
# 	Total time: 90.90 seconds
#
# 	Sigma: 4 Iters: 5
# 	R Background	 Value: 47.94	 RMS: 11.91
# 	G Background	 Value: 73.33	 RMS: 13.89
# 	B Background	 Value: 45.81	 RMS: 12.42
# 	Total time: 60.53 seconds
#
# 	Sigma: 4 Iters: 7
# 	R Background	 Value: 47.89	 RMS: 11.82
# 	G Background	 Value: 73.14	 RMS: 13.62
# 	B Background	 Value: 45.74	 RMS: 12.23
# 	Total time: 73.06 seconds
#
# 	Sigma: 4 Iters: 10
# 	R Background	 Value: 47.89	 RMS: 11.82
# 	G Background	 Value: 73.12	 RMS: 13.61
# 	B Background	 Value: 45.74	 RMS: 12.23
# 	Total time: 91.34 seconds
#
# 	Sigma: 5 Iters: 5
# 	R Background	 Value: 48.36	 RMS: 13.03
# 	G Background	 Value: 73.99	 RMS: 15.92
# 	B Background	 Value: 46.43	 RMS: 13.83
# 	Total time: 62.00 seconds
#
# 	Sigma: 5 Iters: 7
# 	R Background	 Value: 48.31	 RMS: 12.87
# 	G Background	 Value: 73.88	 RMS: 15.42
# 	B Background	 Value: 46.32	 RMS: 13.49
# 	Total time: 73.18 seconds
#
# 	Sigma: 5 Iters: 10
# 	R Background	 Value: 48.31	 RMS: 12.87
# 	G Background	 Value: 73.86	 RMS: 15.33
# 	B Background	 Value: 46.32	 RMS: 13.48
# 	Total time: 94.63 seconds
#
# 	<photutils.background.core.MMMBackground object at 0x7fd6b02aa4e0>
# 	<photutils.background.background_2d.BkgZoomInterpolator object at 0x7fd6b02aa550>
# 	Sigma: 3 Iters: 5
# 	R Background	 Value: 45.29	 RMS: 10.77
# 	G Background	 Value: 69.60	 RMS: 12.10
# 	B Background	 Value: 43.32	 RMS: 11.02
# 	Total time: 64.28 seconds
#
# 	Sigma: 3 Iters: 7
# 	R Background	 Value: 45.13	 RMS: 10.73
# 	G Background	 Value: 69.71	 RMS: 11.91
# 	B Background	 Value: 43.30	 RMS: 10.89
# 	Total time: 77.09 seconds
#
# 	Sigma: 3 Iters: 10
# 	R Background	 Value: 45.13	 RMS: 10.73
# 	G Background	 Value: 69.71	 RMS: 11.91
# 	B Background	 Value: 43.30	 RMS: 10.87
# 	Total time: 93.82 seconds
#
# 	Sigma: 4 Iters: 5
# 	R Background	 Value: 44.71	 RMS: 11.91
# 	G Background	 Value: 68.19	 RMS: 13.89
# 	B Background	 Value: 42.31	 RMS: 12.42
# 	Total time: 63.70 seconds
#
# 	Sigma: 4 Iters: 7
# 	R Background	 Value: 44.79	 RMS: 11.82
# 	G Background	 Value: 68.45	 RMS: 13.62
# 	B Background	 Value: 42.65	 RMS: 12.23
# 	Total time: 86.03 seconds
#
# 	Sigma: 4 Iters: 10
# 	R Background	 Value: 44.79	 RMS: 11.82
# 	G Background	 Value: 68.45	 RMS: 13.61
# 	B Background	 Value: 42.65	 RMS: 12.23
# 	Total time: 93.23 seconds
#
# 	Sigma: 5 Iters: 5
# 	R Background	 Value: 44.17	 RMS: 13.03
# 	G Background	 Value: 66.89	 RMS: 15.92
# 	B Background	 Value: 40.99	 RMS: 13.83
# 	Total time: 63.46 seconds
#
# 	Sigma: 5 Iters: 7
# 	R Background	 Value: 44.15	 RMS: 12.87
# 	G Background	 Value: 67.22	 RMS: 15.42
# 	B Background	 Value: 41.45	 RMS: 13.49
# 	Total time: 77.24 seconds
#
# 	Sigma: 5 Iters: 10
# 	R Background	 Value: 44.16	 RMS: 12.87
# 	G Background	 Value: 67.31	 RMS: 15.33
# 	B Background	 Value: 41.50	 RMS: 13.48
# 	Total time: 94.43 seconds
#
# 	Box: 11 12
# 	<photutils.background.core.SExtractorBackground object at 0x7fd6b02aa080>
# 	<photutils.background.background_2d.BkgZoomInterpolator object at 0x7fd6b02aa550>
# 	Sigma: 3 Iters: 5
# 	R Background	 Value: 46.10	 RMS: 10.06
# 	G Background	 Value: 70.14	 RMS: 11.37
# 	B Background	 Value: 43.95	 RMS: 10.16
# 	Total time: 101.82 seconds
#
# 	Sigma: 3 Iters: 7
# 	R Background	 Value: 46.10	 RMS: 10.06
# 	G Background	 Value: 70.15	 RMS: 11.34
# 	B Background	 Value: 43.95	 RMS: 10.16
# 	Total time: 114.24 seconds
#
# 	Sigma: 3 Iters: 10
# 	R Background	 Value: 46.10	 RMS: 10.06
# 	G Background	 Value: 70.16	 RMS: 11.34
# 	B Background	 Value: 43.95	 RMS: 10.16
# 	Total time: 130.24 seconds
#
# 	Sigma: 4 Iters: 5
# 	R Background	 Value: 45.96	 RMS: 10.43
# 	G Background	 Value: 69.50	 RMS: 12.52
# 	B Background	 Value: 43.55	 RMS: 10.78
# 	Total time: 101.26 seconds
#
# 	Sigma: 4 Iters: 7
# 	R Background	 Value: 45.96	 RMS: 10.43
# 	G Background	 Value: 69.52	 RMS: 12.50
# 	B Background	 Value: 43.55	 RMS: 10.78
# 	Total time: 122.52 seconds
#
# 	Sigma: 4 Iters: 10
# 	R Background	 Value: 45.96	 RMS: 10.43
# 	G Background	 Value: 69.52	 RMS: 12.50
# 	B Background	 Value: 43.55	 RMS: 10.78
# 	Total time: 129.43 seconds
#
# 	Sigma: 5 Iters: 5
# 	R Background	 Value: 45.83	 RMS: 10.50
# 	G Background	 Value: 68.93	 RMS: 13.63
# 	B Background	 Value: 43.04	 RMS: 11.11
# 	Total time: 101.36 seconds
#
# 	Sigma: 5 Iters: 7
# 	R Background	 Value: 45.83	 RMS: 10.50
# 	G Background	 Value: 68.93	 RMS: 13.63
# 	B Background	 Value: 43.04	 RMS: 11.11
# 	Total time: 111.51 seconds
#
# 	Sigma: 5 Iters: 10
# 	R Background	 Value: 45.83	 RMS: 10.50
# 	G Background	 Value: 68.93	 RMS: 13.63
# 	B Background	 Value: 43.04	 RMS: 11.11
# 	Total time: 138.04 seconds
#
# 	<photutils.background.core.MedianBackground object at 0x7fd6b02aa198>
# 	<photutils.background.background_2d.BkgZoomInterpolator object at 0x7fd6b02aa550>
# 	Sigma: 3 Iters: 5
# 	R Background	 Value: 46.50	 RMS: 10.06
# 	G Background	 Value: 71.00	 RMS: 11.37
# 	B Background	 Value: 44.50	 RMS: 10.16
# 	Total time: 97.80 seconds
#
# 	Sigma: 3 Iters: 7
# 	R Background	 Value: 46.50	 RMS: 10.06
# 	G Background	 Value: 71.00	 RMS: 11.34
# 	B Background	 Value: 44.50	 RMS: 10.16
# 	Total time: 108.04 seconds
#
# 	Sigma: 3 Iters: 10
# 	R Background	 Value: 46.50	 RMS: 10.06
# 	G Background	 Value: 71.00	 RMS: 11.34
# 	B Background	 Value: 44.50	 RMS: 10.16
# 	Total time: 125.87 seconds
#
# 	Sigma: 4 Iters: 5
# 	R Background	 Value: 47.00	 RMS: 10.43
# 	G Background	 Value: 71.00	 RMS: 12.52
# 	B Background	 Value: 44.50	 RMS: 10.78
# 	Total time: 100.15 seconds
#
# 	Sigma: 4 Iters: 7
# 	R Background	 Value: 47.00	 RMS: 10.43
# 	G Background	 Value: 71.00	 RMS: 12.50
# 	B Background	 Value: 44.50	 RMS: 10.78
# 	Total time: 110.23 seconds
#
# 	Sigma: 4 Iters: 10
# 	R Background	 Value: 47.00	 RMS: 10.43
# 	G Background	 Value: 71.00	 RMS: 12.50
# 	B Background	 Value: 44.50	 RMS: 10.78
# 	Total time: 126.39 seconds
#
# 	Sigma: 5 Iters: 5
# 	R Background	 Value: 47.00	 RMS: 10.50
# 	G Background	 Value: 71.00	 RMS: 13.63
# 	B Background	 Value: 45.00	 RMS: 11.11
# 	Total time: 99.24 seconds
#
# 	Sigma: 5 Iters: 7
# 	R Background	 Value: 47.00	 RMS: 10.50
# 	G Background	 Value: 71.00	 RMS: 13.63
# 	B Background	 Value: 45.00	 RMS: 11.11
# 	Total time: 109.24 seconds
#
# 	Sigma: 5 Iters: 10
# 	R Background	 Value: 47.00	 RMS: 10.50
# 	G Background	 Value: 71.00	 RMS: 13.63
# 	B Background	 Value: 45.00	 RMS: 11.11
# 	Total time: 133.34 seconds
#
# 	<photutils.background.core.MeanBackground object at 0x7fd6b02aa208>
# 	<photutils.background.background_2d.BkgZoomInterpolator object at 0x7fd6b02aa550>
# 	Sigma: 3 Iters: 5
# 	R Background	 Value: 47.10	 RMS: 10.06
# 	G Background	 Value: 71.45	 RMS: 11.37
# 	B Background	 Value: 44.90	 RMS: 10.16
# 	Total time: 96.50 seconds
#
# 	Sigma: 3 Iters: 7
# 	R Background	 Value: 47.08	 RMS: 10.06
# 	G Background	 Value: 71.42	 RMS: 11.34
# 	B Background	 Value: 44.90	 RMS: 10.16
# 	Total time: 107.88 seconds
#
# 	Sigma: 3 Iters: 10
# 	R Background	 Value: 47.08	 RMS: 10.06
# 	G Background	 Value: 71.42	 RMS: 11.34
# 	B Background	 Value: 44.90	 RMS: 10.16
# 	Total time: 125.35 seconds
#
# 	Sigma: 4 Iters: 5
# 	R Background	 Value: 47.50	 RMS: 10.43
# 	G Background	 Value: 72.38	 RMS: 12.52
# 	B Background	 Value: 45.39	 RMS: 10.78
# 	Total time: 98.48 seconds
#
# 	Sigma: 4 Iters: 7
# 	R Background	 Value: 47.49	 RMS: 10.43
# 	G Background	 Value: 72.35	 RMS: 12.50
# 	B Background	 Value: 45.39	 RMS: 10.78
# 	Total time: 109.54 seconds
#
# 	Sigma: 4 Iters: 10
# 	R Background	 Value: 47.49	 RMS: 10.43
# 	G Background	 Value: 72.35	 RMS: 12.50
# 	B Background	 Value: 45.39	 RMS: 10.78
# 	Total time: 132.68 seconds
#
# 	Sigma: 5 Iters: 5
# 	R Background	 Value: 47.64	 RMS: 10.50
# 	G Background	 Value: 73.15	 RMS: 13.63
# 	B Background	 Value: 45.72	 RMS: 11.11
# 	Total time: 96.86 seconds
#
# 	Sigma: 5 Iters: 7
# 	R Background	 Value: 47.64	 RMS: 10.50
# 	G Background	 Value: 73.15	 RMS: 13.63
# 	B Background	 Value: 45.72	 RMS: 11.11
# 	Total time: 108.29 seconds
#
# 	Sigma: 5 Iters: 10
# 	R Background	 Value: 47.64	 RMS: 10.50
# 	G Background	 Value: 73.15	 RMS: 13.63
# 	B Background	 Value: 45.72	 RMS: 11.11
# 	Total time: 124.61 seconds
#
# 	<photutils.background.core.MMMBackground object at 0x7fd6b02aa4e0>
# 	<photutils.background.background_2d.BkgZoomInterpolator object at 0x7fd6b02aa550>
# 	Sigma: 3 Iters: 5
# 	R Background	 Value: 45.40	 RMS: 10.06
# 	G Background	 Value: 69.51	 RMS: 11.37
# 	B Background	 Value: 43.39	 RMS: 10.16
# 	Total time: 99.63 seconds
#
# 	Sigma: 3 Iters: 7
# 	R Background	 Value: 45.44	 RMS: 10.06
# 	G Background	 Value: 69.61	 RMS: 11.34
# 	B Background	 Value: 43.43	 RMS: 10.16
# 	Total time: 110.69 seconds
#
# 	Sigma: 3 Iters: 10
# 	R Background	 Value: 45.44	 RMS: 10.06
# 	G Background	 Value: 69.66	 RMS: 11.34
# 	B Background	 Value: 43.43	 RMS: 10.16
# 	Total time: 126.19 seconds
#
# 	Sigma: 4 Iters: 5
# 	R Background	 Value: 44.48	 RMS: 10.43
# 	G Background	 Value: 68.03	 RMS: 12.52
# 	B Background	 Value: 42.22	 RMS: 10.78
# 	Total time: 99.46 seconds
#
# 	Sigma: 4 Iters: 7
# 	R Background	 Value: 44.48	 RMS: 10.43
# 	G Background	 Value: 68.11	 RMS: 12.50
# 	B Background	 Value: 42.22	 RMS: 10.78
# 	Total time: 110.79 seconds
#
# 	Sigma: 4 Iters: 10
# 	R Background	 Value: 44.48	 RMS: 10.43
# 	G Background	 Value: 68.12	 RMS: 12.50
# 	B Background	 Value: 42.22	 RMS: 10.78
# 	Total time: 126.82 seconds
#
# 	Sigma: 5 Iters: 5
# 	R Background	 Value: 44.13	 RMS: 10.50
# 	G Background	 Value: 66.62	 RMS: 13.63
